# %%
from matplotlib import pyplot as plt
import numpy as np
import csv
import math
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, roc_curve, auc, confusion_matrix

# %%
def sigmoid(z):
    import numpy as np
    sigm = 1/(1+np.exp(-z))
    return sigm

def loss(h, y):
    import numpy as np
    temp = np.multiply(y, np.log2(h))
    loss = -np.sum(temp, axis=1)        
    return loss

def normalize(x, interval):
    import numpy as np
    x1 = np.array(x)
    x_normalized =  interval[0] + (x1 - min(x))*(interval[1] - interval[0])/(max(x) - min(x))
    return x_normalized

def add_ones_left(df):
    left_ones = np.ones(df.shape[0])
    df['ones'] = left_ones

    cols = list(df.columns)
    cols = [cols[-1]] + cols[:-1]
    df = df[cols]    
    return df

def softmax(df):
    out = df.copy()
    for i in range(df.shape[0]):
        temp = 0
        for j in range(df.shape[1]):
            temp = temp + math.exp(df[i,j])
        for j in range(df.shape[1]):
            out[i,j] = math.exp(df[i,j])/temp
    return out

# %%
#X_train = np.array(X_train)
X_train = pd.read_csv('har_smartphone/X_train.txt', delimiter = '\s+', header = None)
X_test = pd.read_csv('har_smartphone/X_test.txt', delimiter = '\s+', header = None)
y_train_data = pd.read_csv('har_smartphone/y_train.txt', delimiter = '\s+', header = None)
y_test_data = pd.read_csv('har_smartphone/y_test.txt', delimiter = '\s+', header = None)
#names = list(data.keys())


X_train = add_ones_left(X_train)
X_test  = add_ones_left(X_test)

N_CLASSES = 6
y_train = np.zeros([y_train_data.shape[0], N_CLASSES])
for idx, v in enumerate(y_train_data[0]):
    y_train[idx, v-1] = 1

y_test = np.zeros([y_test_data.shape[0], N_CLASSES])
for idx, v in enumerate(y_test_data[0]):
    y_test[idx, v-1] = 1

# %%
# Out:
# ones    1.000000
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
#           ...
# 556     0.998702
# 557     0.996078
# 558     1.000000
# 559     0.478157
# 560     1.000000
# Length: 562, dtype: float64

# %%
# Inicialize weights
VAL_PROPORTION = 0.3
theta = np.zeros((X_train.shape[1], N_CLASSES))

ls_training = []
ls_val = []

# Learning rate
lr = 0.05

# Threshold
threshold = 0.5

# Number of iterations
iterations = 15000

#Number of additional iterations after a minimum on validation set
MAX_IT_AFTER_MIN = 100
it_after_min = 0
min_cost_val = 2**10 #high number

# Training loop
X_training, X_val, y_training, y_val = train_test_split(X_train, y_train, test_size=VAL_PROPORTION, random_state=42)


for i in range(iterations):    
    it_after_min = it_after_min + 1    
    # Input x Weights
    
    z = np.dot(X_training, theta)    
    # Sigmoid
    h_training = softmax(z)
    # Gradient descent
    gradient = np.dot(X_training.transpose() , h_training - y_training)/y_training.shape[0]
    #print(gradient)
    theta = theta - lr * gradient
    
    h_training = softmax(np.dot(X_training, theta))
    cross_entropy = loss(h_training, y_training).mean()
    ls_training.append(cross_entropy)

    h_val = softmax(np.dot(X_val, theta))
    ls_val.append(loss(h_val, y_val).mean())
    
    if ls_val[-1] < min_cost_val:
        it_after_min = 0
        opt_theta = theta
        min_cost_val = ls_val[-1]
        best_it_idx = i
        
    if it_after_min == MAX_IT_AFTER_MIN:
        print('Iteration: {} -- Training Loss: {} -- Validation Loss: {}'. format(i, ls_training[-1], ls_val[-1]))
        break        
    
    # Print info
    if(i%100 == 0):        
        print('Iteration: {} -- Training Loss: {} -- Validation Loss: {}'. format(i, ls_training[-1], ls_val[-1]))
        print('Amount of iterations after the current minimum loss function on the validation set: {}'.format(it_after_min))
theta = opt_theta
# Out:
# Iteration: 0 -- Training Loss: 2.330832031582953 -- Validation Loss: 2.3281141236214355
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 100 -- Training Loss: 0.9987919422343455 -- Validation Loss: 1.0106533544144622
# Amount of iterations after the current minimum loss function on the validation set: 1
# Iteration: 200 -- Training Loss: 0.604923708729619 -- Validation Loss: 0.6165738827802139
# Amount of iterations after the current minimum loss function on the validation set: 1
# Iteration: 300 -- Training Loss: 0.4250564981002545 -- Validation Loss: 0.431833175487721
# Amount of iterations after the current minimum loss function on the validation set: 1
# Iteration: 400 -- Training Loss: 0.354161724512549 -- Validation Loss: 0.35956057981392003
# Amount of iterations after the current minimum loss function on the validation set: 1
# Iteration: 500 -- Training Loss: 0.3149529814240626 -- Validation Loss: 0.3197783294869745
# Amount of iterations after the current minimum loss function on the validation set: 1
# Iteration: 600 -- Training Loss: 0.2909226871618274 -- Validation Loss: 0.2969322265048709
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 700 -- Training Loss: 0.2721511454074819 -- Validation Loss: 0.2798150867098273
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 800 -- Training Loss: 0.25669889662482587 -- Validation Loss: 0.26578514237133294
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 900 -- Training Loss: 0.2436629583994092 -- Validation Loss: 0.25398566856964366
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1000 -- Training Loss: 0.23246169858013543 -- Validation Loss: 0.24387512009711948
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1100 -- Training Loss: 0.222697441079732 -- Validation Loss: 0.23508417723844643
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1200 -- Training Loss: 0.21408591994315207 -- Validation Loss: 0.22734927287117715
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1300 -- Training Loss: 0.20641691461054476 -- Validation Loss: 0.2204757369858201
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1400 -- Training Loss: 0.199530739913621 -- Validation Loss: 0.21431587939370275
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1500 -- Training Loss: 0.19330342375083476 -- Validation Loss: 0.2087552008245357
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1600 -- Training Loss: 0.18763695165312982 -- Validation Loss: 0.20370332298591573
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1700 -- Training Loss: 0.18245262017393535 -- Validation Loss: 0.19908780731512976
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1800 -- Training Loss: 0.17768637775606158 -- Validation Loss: 0.1948498193621115
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 1900 -- Training Loss: 0.17328547978585435 -- Validation Loss: 0.1909410141338739
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2000 -- Training Loss: 0.16920603747574947 -- Validation Loss: 0.1873212527127465
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2100 -- Training Loss: 0.16541118944257474 -- Validation Loss: 0.18395689869883747
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2200 -- Training Loss: 0.16186971620744015 -- Validation Loss: 0.1808195275651631
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2300 -- Training Loss: 0.15855497555100656 -- Validation Loss: 0.1778849354231464
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2400 -- Training Loss: 0.15544407410077102 -- Validation Loss: 0.17513236838552163
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2500 -- Training Loss: 0.15251721539457633 -- Validation Loss: 0.1725439167877823
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 2600 -- Training Loss: 0.1497571815234606 -- Validation Loss: 0.17010403420011597
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 13400 -- Training Loss: 0.07150283916308282 -- Validation Loss: 0.1011810671219877
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 13500 -- Training Loss: 0.07127557677119839 -- Validation Loss: 0.1009857827855236
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 13600 -- Training Loss: 0.07105083486287073 -- Validation Loss: 0.10079279134689151
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 13700 -- Training Loss: 0.07082856725269372 -- Validation Loss: 0.1006020510281049
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 13800 -- Training Loss: 0.07060872893509572 -- Validation Loss: 0.10041352109461286
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 13900 -- Training Loss: 0.07039127604580722 -- Validation Loss: 0.10022716182190208
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14000 -- Training Loss: 0.07017616582485199 -- Validation Loss: 0.10004293446340992
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14100 -- Training Loss: 0.06996335658099108 -- Validation Loss: 0.0998608012196882
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14200 -- Training Loss: 0.06975280765755285 -- Validation Loss: 0.09968072520875867
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14300 -- Training Loss: 0.06954447939958613 -- Validation Loss: 0.09950267043760755
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14400 -- Training Loss: 0.06933833312227629 -- Validation Loss: 0.099326601774766
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14500 -- Training Loss: 0.06913433108056749 -- Validation Loss: 0.09915248492392816
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14600 -- Training Loss: 0.0689324364399371 -- Validation Loss: 0.09898028639856074
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14700 -- Training Loss: 0.06873261324827143 -- Validation Loss: 0.09880997349745904
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14800 -- Training Loss: 0.06853482640879402 -- Validation Loss: 0.09864151428120874
# Amount of iterations after the current minimum loss function on the validation set: 0
# Iteration: 14900 -- Training Loss: 0.06833904165400016 -- Validation Loss: 0.09847487754951308
# Amount of iterations after the current minimum loss function on the validation set: 0

# %%
plt.plot(ls_val, color = 'red', label="Cost Function - Validation")
plt.plot(ls_training, color = 'blue', label ="Cost Function - Training")
plt.axvline(x=best_it_idx)
plt.ylim(0, 0.175)
plt.xlabel('Iterations')
plt.ylabel('Cost function')
plt.legend()
plt.show()

# %%
prob = softmax(np.dot(X_test, theta))
y_pred = np.argmax(prob, axis = 1) + 1

# Accuracy
print('Accuracy: {}'.format(np.equal(y_pred ,y_test_data[0]).mean()))

# F1 Score
print('F1 Score: {}'.format(f1_score(y_test_data[0], y_pred, average='weighted')))
# Out:
# Accuracy: 0.9528333898880217
# F1 Score: 0.9526787383485642

# %%
fpr, tpr, _ = roc_curve(np.squeeze(y_test_data[0]), y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8aa563d209d9> in <module>
# ----> 1 fpr, tpr, _ = roc_curve(np.squeeze(y_test_data[0]), y_pred)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     620     """
#     621     fps, tps, thresholds = _binary_clf_curve(
# --> 622         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     623
#     624     # Attempt to drop thresholds corresponding to points in between and
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     394     if not (y_type == "binary" or
#     395             (y_type == "multiclass" and pos_label is not None)):
# --> 396         raise ValueError("{0} format is not supported".format(y_type))
#     397
#     398     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported

# %%
# Accuracy
print('Accuracy: {}'.format(np.equal(y_pred ,y_test_data[0]).mean()))

# F1 Score
print('F1 Score: {}'.format(f1_score(y_test_data[0], y_pred, average='weighted')))
# Out:
# Accuracy: 0.9528333898880217
# F1 Score: 0.9526787383485642

# %%
normalize = False
cm = confusion_matrix(y_test_data[0], y_pred)
cmap = plt.cm.Blues
classes = ['1', '2', '3', '4', '5', '6']

for normalize in [False, True]:

    # Normalization
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title = 'Normalized confusion matrix'
    else:
        title = 'Confusion matrix, without normalization'

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    
    
    ax.set_ylim(5.5, -0.5)
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
ax.get_ylim()
# Out:
# (5.0, 0.0)
